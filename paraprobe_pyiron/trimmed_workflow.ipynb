# %%
from pyiron_base import Project
from paraprobe_job import ParaprobeJob

# %%
pr = Project('a4')

# %%
job = job = pr.create_job(job_type=ParaprobeJob, job_name="a1j")
job.pos_file = "../data/R31_06365-v02.pos"
job.rrng_file = "../data/R31_06365-v02.rrng"

# %%
job.analyse_ranger()

# %%
job.analyse_nanochem

# %%
job.run()
# Out:
# The job a1j was saved and received the ID: 525
# The job a1j_ranger was saved and received the ID: 526

# %%
job.output
# Out:
# DataContainer({'log': DataContainer({'configure': DataContainer({'transcoder': 'Computing SHA256 hash for file named /mnt/c/Users/menon/Documents/winrepos/pyiron-apt/paraprobe_pyiron/a4/a1j_ranger_hdf5/a1j_ranger/R31_06365-v02.pos\nComputing SHA256 hash for file named /mnt/c/Users/menon/Documents/winrepos/pyiron-apt/paraprobe_pyiron/a4/a1j_ranger_hdf5/a1j_ranger/R31_06365-v02.rrng\nInspecting whether NeXus/HDF5 is used...\nparaprobe-transcoder will be needed to transcode vendor\nfile formats for reconstruction and ranging into HDF5.\nTools will read recon/ranging from the transcoder results file.\nWriting configuration file ...\nPARAPROBE.Transcoder.Config.SimID.636502001.nxs was written successfully.\n', 'ranger': 'Using old transcoder/ranger file format, this will become deprecated!\nComputing SHA256 hash for file named /mnt/c/Users/menon/Documents/winrepos/pyiron-apt/paraprobe_pyiron/a4/a1j_ranger_hdf5/a1j_ranger/PARAPROBE.Transcoder.Results.SimID.636502001.nxs\nComputing SHA256 h
# ...

# %%
class Output:
    def __init__(self):
        self._ion = 2
    
    @property
    def ion(self):
        """
        Set of atoms of a molecular ion or fragment in e.g. ToF mass spectrometry.
        
        url: https://fairmat-experimental.github.io/nexus-fairmat-proposal/9636feecb79bb32b828b1a9804269573256d7696/classes/contributed_definitions/NXion.html#nxion
        """
        return self._ion

# %%
output = Output()

# %%
output.ion?
# Out:
# Type:        property
# String form: <property object at 0x7f4e3b1bd450>
# Docstring:
# Set of atoms of a molecular ion or fragment in e.g. ToF mass spectrometry.
#
# url: https://fairmat-experimental.github.io/nexus-fairmat-proposal/9636feecb79bb32b828b1a9804269573256d7696/classes/contributed_definitions/NXion.html#nxion

# %%
job.output.ion
